# %% [markdown]
# <a href="https://colab.research.google.com/github/chaiminwoo0223/Computer-Vision/blob/main/Class9/program01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10을 분류하는 비전 트랜스포머 구현하기

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import keras

from keras import layers
from keras.losses import SparseCategoricalCrossentropy
from keras.optimizers import Adam

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
n_class = 10
img_siz = (32, 32, 3)
patch_siz = 4
p2 = (img_siz[0]//patch_siz) ** 2
d_model = 64
h = 8
N = 6
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.p_siz = patch_size

    def call(self, img):
        batch_size = tf.shape(img)[0]
        patches = tf.image.extract_patches(images=img, sizes=[1, self.p_siz, self.p_siz, 1], strides=[1, self.p_siz, self.p_siz, 1], rates=[1,1,1,1], padding='VALID')
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEncoder(layers.Layer):
    def __init__(self, p2, d_model):
        super(PatchEncoder, self).__init__()
        self.p2 = p2
        self.projection = layers.Dense(units = d_model)
        self.position_embedding = layers.Embedding(input_dim=p2, output_dim=d_model)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.p2, delta=1)
        encoded = self.projection(patch)+self.position_embedding(positions)
        return encoded

def create_vit_classifier():
    input = layers.Input(shape=(img_siz))
    nor = layers.Normalization()(input)
    patches=Patches(patch_siz)(nor)
    x = PatchEncoder(p2, d_model)(patches)

    for _ in range(N):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        x2 = layers.MultiHeadAttention(num_heads=h, key_dim=d_model//h, dropout=0.1)(x1,x1)
        x3 = layers.Add()([x2,x])
        x4 = layers.LayerNormalization(epsilon=1e-6)(x3)
        x5 = layers.Dense(d_model*2, activation=tf.nn.gelu)(x4)
        x6 = layers.Dropout(0.1)(x5)
        x7 = layers.Dense(d_model, activation=tf.nn.gelu)(x6)
        x8 = layers.Dropout(0.1)(x7)
        x = layers.Add()([x8,x3])

    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(2048, activation=tf.nn.gelu)(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1024, activation=tf.nn.gelu)(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(n_class, activation='softmax')(x)
    model = keras.Model(inputs=input, outputs=output)
    return model

# %%
model = create_vit_classifier()
model.layers[1].adapt(x_train)
model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
hist = model.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test), verbose=1)
res = model.evaluate(x_test, y_test, verbose=0)
print('정확률 =', res[1]*100)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 391/391 [==============================] - 46s 58ms/step - loss: 1.7840 - accuracy: 0.3758 - val_loss: 1.2949 - val_accuracy: 0.5362
# Epoch 2/50
# 391/391 [==============================] - 22s 56ms/step - loss: 1.3875 - accuracy: 0.5031 - val_loss: 1.1876 - val_accuracy: 0.5828
# Epoch 3/50
# 391/391 [==============================] - 23s 60ms/step - loss: 1.2324 - accuracy: 0.5579 - val_loss: 1.0680 - val_accuracy: 0.6206
# Epoch 4/50
# 391/391 [==============================] - 22s 56ms/step - loss: 1.1239 - accuracy: 0.6018 - val_loss: 0.9898 - val_accuracy: 0.6529
# Epoch 5/50
# 391/391 [==============================] - 22s 56ms/step - loss: 1.0363 - accuracy: 0.6320 - val_loss: 0.9143 - val_accuracy: 0.6831
# Epoch 6/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.9619 - accuracy: 0.6596 - val_loss: 0.8705 - val_accuracy: 0.6995
# Epoch 7/50
# 391/391 [==============================] - 22s 57ms/step - loss: 0.8982 - accuracy: 0.6836 - val_loss: 0.8630 - val_accuracy: 0.7010
# Epoch 8/50
# 391/391 [==============================] - 22s 55ms/step - loss: 0.8404 - accuracy: 0.7012 - val_loss: 0.8203 - val_accuracy: 0.7158
# Epoch 9/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.7882 - accuracy: 0.7231 - val_loss: 0.8007 - val_accuracy: 0.7231
# Epoch 10/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.7358 - accuracy: 0.7405 - val_loss: 0.7689 - val_accuracy: 0.7345
# Epoch 11/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.6850 - accuracy: 0.7602 - val_loss: 0.7529 - val_accuracy: 0.7423
# Epoch 12/50
# 391/391 [==============================] - 23s 58ms/step - loss: 0.6460 - accuracy: 0.7717 - val_loss: 0.7335 - val_accuracy: 0.7524
# Epoch 13/50
# 391/391 [==============================] - 22s 55ms/step - loss: 0.5962 - accuracy: 0.7886 - val_loss: 0.7288 - val_accuracy: 0.7511
# Epoch 14/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.5613 - accuracy: 0.8021 - val_loss: 0.7116 - val_accuracy: 0.7576
# Epoch 15/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.5307 - accuracy: 0.8147 - val_loss: 0.7188 - val_accuracy: 0.7593
# Epoch 16/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.4842 - accuracy: 0.8287 - val_loss: 0.7265 - val_accuracy: 0.7623
# Epoch 17/50
# 391/391 [==============================] - 22s 57ms/step - loss: 0.4605 - accuracy: 0.8373 - val_loss: 0.7328 - val_accuracy: 0.7576
# Epoch 18/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.4357 - accuracy: 0.8477 - val_loss: 0.7223 - val_accuracy: 0.7686
# Epoch 19/50
# 391/391 [==============================] - 22s 57ms/step - loss: 0.4104 - accuracy: 0.8543 - val_loss: 0.7386 - val_accuracy: 0.7666
# Epoch 20/50
# 391/391 [==============================] - 23s 60ms/step - loss: 0.3827 - accuracy: 0.8658 - val_loss: 0.7584 - val_accuracy: 0.7656
# Epoch 21/50
# 391/391 [==============================] - 23s 60ms/step - loss: 0.3654 - accuracy: 0.8722 - val_loss: 0.7481 - val_accuracy: 0.7701
# Epoch 22/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.3399 - accuracy: 0.8803 - val_loss: 0.7919 - val_accuracy: 0.7747
# Epoch 23/50
# 391/391 [==============================] - 23s 58ms/step - loss: 0.3207 - accuracy: 0.8899 - val_loss: 0.8522 - val_accuracy: 0.7681
# Epoch 24/50
# 391/391 [==============================] - 23s 58ms/step - loss: 0.3137 - accuracy: 0.8899 - val_loss: 0.8051 - val_accuracy: 0.7716
# Epoch 25/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.2980 - accuracy: 0.8976 - val_loss: 0.8491 - val_accuracy: 0.7626
# Epoch 26/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.2769 - accuracy: 0.9049 - val_loss: 0.8283 - val_accuracy: 0.7703
# Epoch 27/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.2719 - accuracy: 0.9066 - val_loss: 0.9310 - val_accuracy: 0.7679
# Epoch 28/50
# 391/391 [==============================] - 23s 58ms/step - loss: 0.2617 - accuracy: 0.9098 - val_loss: 0.8689 - val_accuracy: 0.7775
# Epoch 29/50
# 391/391 [==============================] - 22s 55ms/step - loss: 0.2474 - accuracy: 0.9161 - val_loss: 0.8620 - val_accuracy: 0.7731
# Epoch 30/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.2342 - accuracy: 0.9205 - val_loss: 0.8448 - val_accuracy: 0.7721
# Epoch 31/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.2230 - accuracy: 0.9241 - val_loss: 0.8522 - val_accuracy: 0.7768
# Epoch 32/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.2315 - accuracy: 0.9218 - val_loss: 0.8400 - val_accuracy: 0.7761
# Epoch 33/50
# 391/391 [==============================] - 21s 55ms/step - loss: 0.2166 - accuracy: 0.9267 - val_loss: 0.8237 - val_accuracy: 0.7770
# Epoch 34/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.2089 - accuracy: 0.9291 - val_loss: 0.9235 - val_accuracy: 0.7764
# Epoch 35/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.2013 - accuracy: 0.9322 - val_loss: 0.8831 - val_accuracy: 0.7793
# Epoch 36/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1957 - accuracy: 0.9343 - val_loss: 0.9154 - val_accuracy: 0.7771
# Epoch 37/50
# 391/391 [==============================] - 22s 55ms/step - loss: 0.1844 - accuracy: 0.9383 - val_loss: 0.8592 - val_accuracy: 0.7737
# Epoch 38/50
# 391/391 [==============================] - 22s 55ms/step - loss: 0.1817 - accuracy: 0.9403 - val_loss: 0.8576 - val_accuracy: 0.7744
# Epoch 39/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1742 - accuracy: 0.9413 - val_loss: 0.8735 - val_accuracy: 0.7717
# Epoch 40/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1794 - accuracy: 0.9409 - val_loss: 0.9013 - val_accuracy: 0.7781
# Epoch 41/50
# 391/391 [==============================] - 23s 58ms/step - loss: 0.1680 - accuracy: 0.9443 - val_loss: 0.8646 - val_accuracy: 0.7853
# Epoch 42/50
# 391/391 [==============================] - 22s 55ms/step - loss: 0.1676 - accuracy: 0.9435 - val_loss: 0.9008 - val_accuracy: 0.7793
# Epoch 43/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1639 - accuracy: 0.9468 - val_loss: 0.8638 - val_accuracy: 0.7754
# Epoch 44/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1624 - accuracy: 0.9468 - val_loss: 0.8623 - val_accuracy: 0.7748
# Epoch 45/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.1608 - accuracy: 0.9470 - val_loss: 0.9028 - val_accuracy: 0.7758
# Epoch 46/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1593 - accuracy: 0.9479 - val_loss: 0.8124 - val_accuracy: 0.7809
# Epoch 47/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1441 - accuracy: 0.9523 - val_loss: 0.8583 - val_accuracy: 0.7779
# Epoch 48/50
# 391/391 [==============================] - 23s 60ms/step - loss: 0.1483 - accuracy: 0.9511 - val_loss: 0.8281 - val_accuracy: 0.7763
# Epoch 49/50
# 391/391 [==============================] - 22s 56ms/step - loss: 0.1449 - accuracy: 0.9530 - val_loss: 0.8411 - val_accuracy: 0.7820
# Epoch 50/50
# 391/391 [==============================] - 23s 59ms/step - loss: 0.1403 - accuracy: 0.9533 - val_loss: 0.8580 - val_accuracy: 0.7588
# 정확률 = 75.88000297546387

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.grid()
plt.show()
